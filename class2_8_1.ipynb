# %%
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
col_image = Image.open('/home/raja/kmit/classes/TCGA-CS-4938-01Z-00-DX1_20x_17248_8864_256x256.png')

# %%
col_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F9EF42ABEF0>

# %%
#an L mode image, that means it is a single channel image - normally interpreted as greyscale. 
#The L means that is just stores the Luminance
gray = col_image.convert('L')

# %%
gray
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9EF3F9A828>

# %%
gray.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-00bf242f76ed> in <module>
# ----> 1 gray.shape
#
# AttributeError: 'Image' object has no attribute 'shape'

# %%
type(gray)
# Out:
# PIL.Image.Image

# %%
bw = gray.point(lambda x: 0 if x<128 else 255, '1')

# %%
bw
# Out:
# <PIL.Image.Image image mode=1 size=256x256 at 0x7F9EF2762400>

# %%
#change image as np array
np_gray1=np.array(gray)

# %%
np_gray1.shape
# Out:
# (256, 256)

# %%
np_gray1[0,0]

# %%
#change image as np array
np_col_image=np.array(col_image)

# %%
np_col_image.shape
# Out:
# (256, 256, 3)

# %%
np_col_image[0,0,:]
# Out:
# array([177,  90, 145], dtype=uint8)

# %%
gray_ravel=np_gray1.ravel()

# %%
gray_ravel.shape
# Out:
# (65536,)

# %%
gray_ravel[0]
# Out:
# 122

# %%
color_ravel=np_col_image.ravel()

# %%
color_ravel.shape
# Out:
# (196608,)

# %%
color_ravel[0],color_ravel[1],color_ravel[2]
# Out:
# (177, 90, 145)
