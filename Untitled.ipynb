# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
f = np.fft.fft2(gray)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(gray, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
from PIL import Image

col = Image.open("/home/raja/kmit/classes/brain.png")
gray = col.convert('L')

# %%
gray
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F1CDC0D4FD0>

# %%
img= Image.open("/home/raja/kmit/classes/brain.png")
gray = col.convert('L')
rows,cols = gray.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-22a926c822f2> in <module>
#       1 img= Image.open("/home/raja/kmit/classes/brain.png")
#       2 gray = col.convert('L')
# ----> 3 rows,cols = gray.shape
#
# AttributeError: 'Image' object has no attribute 'shape'

# %%
rows, cols =gray.shape
crow,ccol = rows/2 , cols/2
fshift[crow-30:crow+30, ccol-30:ccol+30] = 0
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

plt.subplot(131),plt.imshow(gray, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img_back, cmap = 'gray')print rows,cols
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4ea210d13002> in <module>
# ----> 1 rows, cols =gray.shape
#       2 crow,ccol = rows/2 , cols/2
#       3 fshift[crow-30:crow+30, ccol-30:ccol+30] = 0
#       4 f_ishift = np.fft.ifftshift(fshift)
#       5 img_back = np.fft.ifft2(f_ishift)
#
# AttributeError: 'Image' object has no attribute 'shape'
