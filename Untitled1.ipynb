# %%
from PIL import Image

# %%
col_image = Image.open('/home/kmit/Downloads/images/TCGA-CS-4938-01Z-00-DX1_20x_17248_8864_256x256.png')

# %%
col_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F4AE408D748>

# %%
#an L mode image, that means it is a single channel image - normally interpreted as greyscale. 
#The L means that is just stores the Luminance
gray = col_image.convert('L')

# %%
gray
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F4ACEEB4358>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# !pip3 install opencv-python --user

# %%
# !pip3 install matplotlib --user

# %%
hist_input= cv2.imread('/home/kmit/Downloads/images/TCGA-CS-4938-01Z-00-DX1_20x_17248_8864_256x256.png',0)
plt.hist(hist_input.ravel(),256,[0,256]); plt.show()

# %%
hist_input
# Out:
# array([[181, 172, 163, ...,  93, 109, 122],
#        [191, 177, 157, ...,  98, 116, 124],
#        [161, 164, 156, ..., 101, 120, 130],
#        ...,
#        [186, 168, 145, ..., 143, 113, 126],
#        [154, 146, 141, ..., 147, 114, 129],
#        [140, 148, 156, ..., 170, 135, 140]], dtype=uint8)

# %%
hist_input.shape
# Out:
# (256, 256)

# %%
new_im = Image.fromarray(hist_input)

# %%
new_im
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F4AAFD0E5C0>
