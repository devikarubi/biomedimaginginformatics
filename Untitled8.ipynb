# %%
import numpy as np

# %%
nx, ny = (3, 2)
x = np.linspace(0, 1, nx)
y = np.linspace(0, 1, ny)
xv, yv = np.meshgrid(x, y)

# %%
xv
# Out:
# array([[0. , 0.5, 1. ],
#        [0. , 0.5, 1. ]])

# %%
yv
# Out:
# array([[0., 0., 0.],
#        [1., 1., 1.]])

# %%
xv, yv = np.meshgrid(x, y, sparse=True)  # make sparse output arrays

# %%
xv
# Out:
# array([[0. , 0.5, 1. ]])

# %%
yv
# Out:
# array([[0.],
#        [1.]])

# %%
from matplotlib import pyplot as plt

# %%
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
z = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)
h = plt.contourf(x,y,z)

# %%
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline

# %%
image = cv2.imread('/home/raja/kmit/classes/bio_speckle.jpeg')
new_image = cv2.GaussianBlur(image, (9, 9),0)

# %%
np_image=np.asarray(new_image)

# %%
np_image.mean(),np_image.var()
# Out:
# (65.61137309292648, 2090.5103917544016)

# %%
np_original=np.asarray(image)

# %%
np_original.mean(),np_original.var()
# Out:
# (65.27685753913215, 2147.375123233717)

# %%
mean=65
var=2147

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def plt_plot_bivariate_normal_pdf(x, y, z):
  fig = plt.figure(figsize=(12, 6))
  ax = fig.gca(projection='3d')
  ax.plot_surface(x, y, z, 
                  cmap=cm.coolwarm,
                  linewidth=0, 
                  antialiased=True)
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_zlabel('z');
  plt.show()

# %%
plt_plot_bivariate_normal_pdf(6,4,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-8455c28707d9> in <module>
# ----> 1 plt_plot_bivariate_normal_pdf(6,4,10)
#
# <ipython-input-28-99b8dfb3ea4b> in plt_plot_bivariate_normal_pdf(x, y, z)
#       9                   cmap=cm.coolwarm,
#      10                   linewidth=0,
# ---> 11                   antialiased=True)
#      12   ax.set_xlabel('x')
#      13   ax.set_ylabel('y')
#
# ~/kmit/research/pathomics/pathomics/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1611         had_data = self.has_data()
#    1612
# -> 1613         if Z.ndim != 2:
#    1614             raise ValueError("Argument Z must be 2-dimensional.")
#    1615         if np.any(np.isnan(Z)):
#
# AttributeError: 'int' object has no attribute 'ndim'

# %%
 X = np.arange(0,255,1)

# %%
X.shape
# Out:
# (255,)

# %%
  X, Y = np.meshgrid(X, Y)

# %%
Y = np.arange(0,255,1)

# %%
for i in range(len(np_image)):
    for j in range(len(np_image[i])):
        z=np_image[i][j]
        plt_plot_bivariate_normal_pdf(i,j,z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-73ac5ab41a5a> in <module>
#       2     for j in range(len(np_image[i])):
#       3         z=np_image[i][j]
# ----> 4         plt_plot_bivariate_normal_pdf(i,j,z)
#
# <ipython-input-28-99b8dfb3ea4b> in plt_plot_bivariate_normal_pdf(x, y, z)
#       9                   cmap=cm.coolwarm,
#      10                   linewidth=0,
# ---> 11                   antialiased=True)
#      12   ax.set_xlabel('x')
#      13   ax.set_ylabel('y')
#
# ~/kmit/research/pathomics/pathomics/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1612
#    1613         if Z.ndim != 2:
# -> 1614             raise ValueError("Argument Z must be 2-dimensional.")
#    1615         if np.any(np.isnan(Z)):
#    1616             cbook._warn_external(
#
# ...

# %%
import matplotlib.pyplot as plt
from copy import deepcopy
from PIL import Image
from math import cos, sin

image = Image.open('/home/raja/kmit/classes/bio_speckle.jpeg')
gray = image.convert('L')
img1 = np.asarray(gray)

# %%
plt_plot_bivariate_normal_pdf(X,Y,img1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-7a4df9aafe45> in <module>
# ----> 1 plt_plot_bivariate_normal_pdf(X,Y,img1)
#
# <ipython-input-28-99b8dfb3ea4b> in plt_plot_bivariate_normal_pdf(x, y, z)
#       9                   cmap=cm.coolwarm,
#      10                   linewidth=0,
# ---> 11                   antialiased=True)
#      12   ax.set_xlabel('x')
#      13   ax.set_ylabel('y')
#
# ~/kmit/research/pathomics/pathomics/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1619
#    1620         # TODO: Support masked arrays
# -> 1621         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#    1622         rows, cols = Z.shape
#    1623
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ...

# %%
import numpy as np
import cv2

img = cv2.imread('people.jpg')
grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# edge_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen_kernel = np.array([[0,-1,0], [-1,5,-1], [0,-1,0]])
img = cv2.filter2D(grayscale, -1, sharpen_kernel)

# Smooth out image
# blur = cv2.medianBlur(img, 3)
blur = cv2.GaussianBlur(img, (3,3), 0)

cv2.imshow('img',img)
cv2.imwrite('img.png',img)
cv2.imshow('blur',blur)
cv2.waitKey(0)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
from scipy.stats import multivariate_normal

x, y = np.mgrid[0:30,0:255]

# Need an (N, 2) array of (x, y) pairs.
xy = np.column_stack([x.flat, y.flat])

mu = np.array([0.0, 0.0])

sigma = np.array([.5, .5])
covariance = np.diag(sigma**2)

z = multivariate_normal.pdf(xy, mean=mu, cov=covariance)

# Reshape back to a (30, 30) grid.
z = z.reshape(x.shape)





fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
