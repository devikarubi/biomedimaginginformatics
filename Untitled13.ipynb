# %%
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
col_image = Image.open('/home/kmit/Downloads/images/TCGA-02-0001-01Z-00-DX2_20x_15424_10336_256x256.png')

# %%
col_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F74B7EECEF0>

# %%
gray = col_image.convert('L')

# %%
gray
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F74E8266C18>

# %%
bw = gray.point(lambda x: 0 if x<128 else 255, '1')

# %%
bw
# Out:
# <PIL.Image.Image image mode=1 size=256x256 at 0x7F74B7C0C7B8>

# %%
np_gray1=np.array(gray)

# %%
np_gray1.shape
# Out:
# (256, 256)

# %%
np_gray1[0,0]
# Out:
# 238

# %%
#change image as np array
np_col_image=np.array(col_image)

# %%
np_col_image.shape
# Out:
# (256, 256, 3)

# %%
np_col_image[0,0,:]
# Out:
# array([237, 237, 247], dtype=uint8)
