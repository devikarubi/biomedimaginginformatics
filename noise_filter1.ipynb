# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.blur(img,(5,5))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread('/home/kmit/Downloads/images/medical_noise.jpeg')

blur = cv2.blur(img1,(5,5))

plt.subplot(121),plt.imshow(img1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.GaussianBlur(img,(5,5),0)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.GaussianBlur(img1,(5,5),0)

plt.subplot(121),plt.imshow(img1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

median = cv2.medianBlur(img,5)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.bilateralFilter(img1,9,75,75)

plt.subplot(121),plt.imshow(img1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img2 = cv2.imread('/home/kmit/Downloads/images/noise_face.jpeg')

blur = cv2.blur(img2,(5,5))

plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.GaussianBlur(img2,(5,5),0)

plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

median = cv2.medianBlur(img2,5)

plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.bilateralFilter(img2,9,75,75)

plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img3 = cv2.imread('/home/kmit/Downloads/images/parrot.jpeg')

blur = cv2.GaussianBlur(img3,(5,5),0)

plt.subplot(121),plt.imshow(img3),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread('/home/kmit/Dropbox/Devi_DropBox/Devika/kmit/BMI_Course/classes_code/brain.png')

blur = cv2.bilateralFilter(img3,9,75,75)

plt.subplot(121),plt.imshow(img3),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()
